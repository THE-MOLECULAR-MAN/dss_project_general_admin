# %%
# import dataiku
# from dataiku import pandasutils as pdu
# import pandas as pd
from pprint import pprint as pp
from json import dumps

# %%
from dataiku import api_client
client = api_client()

# %%
x = client.get_global_usage_summary(with_per_project=True).raw
# pp(x)
dumps(x,)
