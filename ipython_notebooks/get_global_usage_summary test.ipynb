# %%
# import dataiku
# from dataiku import pandasutils as pdu
# import pandas as pd

# %%
from dataiku import api_client
client = api_client()

# %%
x = client.get_global_usage_summary(with_per_project=False)
xx
